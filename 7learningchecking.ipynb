# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.utils.class_weight import compute_class_weight

# %%
#importing dataset by reading csv file (The data was downloaded from Google Cloud using BIGQUERY)
df=pd.read_csv('/root/code/thesis/codeFolder/LatestDataInUse/csv/coding_challenge.csv')

# %%
df.head(5)
# Out:
#          date  station_number  mean_temp  mean_dew_point  \
# 0  2006-01-24          725300  33.200001       26.799999
# 1  2006-01-25          725300  33.299999       21.400000
# 2  2006-01-26          725300  30.299999       19.700001
# 3  2006-01-27          725300  39.900002       25.299999
# 4  2006-01-28          725300  43.200001       33.799999
#
#    mean_sealevel_pressure  mean_visibility  mean_wind_speed  max_temperature  \
# 0             1008.500000              7.0             15.2        23.000000
# 1             1021.099976             10.0             14.0        28.900000
# 2             1031.400024              9.9              4.6        19.400000
# 3             1027.599976             10.0             10.7        35.599998
# 4             1019.900024              9.4              6.6        35.099998
#
#    total_precipitation  snow_depth    fog   snow   hail  thunder
# 0                  0.0        1.20  False  False  False    False
# 1                  0.0        1.20  False  False  False    False
# 2                  0.0        2.66  False  False  False    False
# 3                  0.0        2.66  False  False  False    False
# 4                  0.0        2.66  False  False  False    False

# %%
df = df.sort_values(by='date') 
df = df.set_index('date')

# %%
df.head()
# Out:
#             station_number  mean_temp  mean_dew_point  mean_sealevel_pressure  \
# date
# 2006-01-24          725300  33.200001       26.799999             1008.500000
# 2006-01-24          725315  34.400002       28.000000             1013.700012
# 2006-01-24          725314  39.400002       24.799999             1018.099976
# 2006-01-24          725326  33.099998       27.000000               22.528572
# 2006-01-24          725327  32.799999       28.100000             1010.299988
#
#             mean_visibility  mean_wind_speed  max_temperature  \
# date
# 2006-01-24              7.0        15.200000             23.0
# 2006-01-24              7.2        17.900000             25.0
# 2006-01-24              8.4         9.400000             24.1
# 2006-01-24              7.6        15.600000             19.4
# 2006-01-24              6.7        16.700001             26.6
#
#             total_precipitation  snow_depth    fog   snow   hail  thunder
# date
# 2006-01-24                 0.00         1.2  False  False  False    False
# 2006-01-24                 0.00         0.0  False  False  False    False
# 2006-01-24                 0.00         0.0  False  False  False    False
# 2006-01-24                 0.01         0.0  False  False  False    False
# 2006-01-24                 0.00         0.0  False  False  False    False

# %%
# Converting the categorical values to numerical values
df['fog'] = df['fog'].astype(int)
df['hail'] = df['hail'].astype(int)
df['thunder'] = df['thunder'].astype(int)
df['snow'] = df['snow'].astype(int)

# %%
df['snow'].value_counts()
# Out:
# 0    13919
# 1     1413
# Name: snow, dtype: int64

# %%
df = df.sort_values(by=['station_number', 'date'])

# %%
df['snow_tomorrow'] = df.groupby('station_number')['snow'].shift(-1)
df.dropna(inplace=True)

# %%
# Create lag features
df['mean_temp_lag_1'] = df.groupby('station_number')['mean_temp'].shift(1)
df['mean_dew_point_lag_1'] = df.groupby('station_number')['mean_dew_point'].shift(1)
df['mean_sealevel_pressure'] = df.groupby('station_number')['mean_sealevel_pressure'].shift(1)
df['mean_visibility_lag_1'] = df.groupby('station_number')['mean_visibility'].shift(1)
df['mean_wind_speed_lag_1'] = df.groupby('station_number')['mean_wind_speed'].shift(1)
df['total_precipitation_lag_1'] = df.groupby('station_number')['total_precipitation'].shift(1)
df['snow_depth'] = df.groupby('station_number')['snow_depth'].shift(1)
df['fog_lag_1'] = df.groupby('station_number')['fog'].shift(1)
df['snow_lag_1'] = df.groupby('station_number')['snow'].shift(1)
df['hail_lag_1'] = df.groupby('station_number')['hail'].shift(1)
df['thunder_lag_1'] = df.groupby('station_number')['thunder'].shift(1)

# %%
df.dropna(inplace=True)

# %%
df.columns
# Out:
# Index(['station_number', 'mean_temp', 'mean_dew_point',
#        'mean_sealevel_pressure', 'mean_visibility', 'mean_wind_speed',
#        'max_temperature', 'total_precipitation', 'snow_depth', 'fog', 'snow',
#        'hail', 'thunder', 'snow_tomorrow', 'mean_temp_lag_1',
#        'mean_dew_point_lag_1', 'mean_visibility_lag_1',
#        'mean_wind_speed_lag_1', 'total_precipitation_lag_1', 'fog_lag_1',
#        'snow_lag_1', 'hail_lag_1', 'thunder_lag_1'],
#       dtype='object')

# %%
features=['station_number', 'mean_temp', 'mean_dew_point',
       'mean_sealevel_pressure', 'mean_visibility', 'mean_wind_speed',
       'total_precipitation', 'snow_depth', 'fog', 'snow',
       'hail', 'thunder', 'mean_temp_lag_1',
       'mean_dew_point_lag_1', 'mean_visibility_lag_1',
       'mean_wind_speed_lag_1', 'total_precipitation_lag_1', 'fog_lag_1',
       'snow_lag_1', 'hail_lag_1', 'thunder_lag_1']

# %%
# Train-test split, ensuring the split is done per station to maintain the time series nature
def train_test_split_per_station(df, test_size=0.2):
    train_data = pd.DataFrame()
    test_data = pd.DataFrame()
    for station in df['station_number'].unique():
        station_data = df[df['station_number'] == station]
        train_station, test_station = train_test_split(station_data, test_size=test_size, shuffle=False)
        train_data = pd.concat([train_data, train_station])
        test_data = pd.concat([test_data, test_station])
    return train_data, test_data

train_data, test_data = train_test_split_per_station(df)
X_train = train_data[features].values
y_train = train_data['snow_tomorrow'].values
X_test = test_data[features].values
y_test = test_data['snow_tomorrow'].values

# Normalizing the features to ensure equal weightage of all the variables
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

#Converting to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1)  # unsqueeze to add a dimension
y_test = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1)

# %%
X_train
# Out:
# tensor([[-1.8892, -0.9182, -1.0240,  ..., -0.3121, -0.3121, -0.3121],
#         [-1.8892, -1.0713, -1.1146,  ..., -0.3121, -0.3121, -0.3121],
#         [-1.8892, -0.5812, -0.8161,  ..., -0.3121, -0.3121, -0.3121],
#         ...,
#         [ 1.4532,  0.9147,  1.1561,  ..., -0.3121, -0.3121, -0.3121],
#         [ 1.4532,  0.6288,  0.9695,  ...,  3.2042,  3.2042,  3.2042],
#         [ 1.4532,  0.7411,  1.1987,  ..., -0.3121, -0.3121, -0.3121]])

# %%
# Defining the neural network model
class SnowForecastModel(nn.Module):
    def __init__(self):
        super(SnowForecastModel, self).__init__()
        self.fc1 = nn.Linear(len(features), 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 1)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        x = self.sigmoid(x)
        return x

# %%
# Function to calculate accuracy
def calculate_accuracy(preds, labels):
    predicted = preds.round()
    correct = (predicted == labels).float()
    accuracy = correct.sum() / len(correct)
    return accuracy*100

# %%
np.unique(y_train)
# Out:
# array([0., 1.], dtype=float32)

# %%
# Ensure y_train is a numpy array
if isinstance(y_train, torch.Tensor):
    y_train_copy = y_train.cpu().numpy()


# Flatten y_train to ensure it's a 1D array
y_train_flat = y_train_copy.flatten()

# Convert to int
y_train_int = y_train_flat.astype(int)

# Calculate class weights
class_weights = compute_class_weight('balanced', classes=np.unique(y_train_int), y=y_train_int)
class_weights = torch.tensor(class_weights, dtype=torch.float32)

# Use class weights in the loss function
criterion = nn.BCEWithLogitsLoss(pos_weight=class_weights[1])

# Instantiating the model, defining the loss function and the optimizer
model = SnowForecastModel()
#criterion = nn.BCELoss()  # Binary Cross Entropy loss for binary classification
optimizer = optim.Adam(model.parameters(), lr=0.00001, weight_decay=0.01)

# Training & evaluating the model
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    optimizer.zero_grad()
    outputs = model(X_train)
    train_loss = criterion(outputs, y_train)
    train_loss.backward()
    optimizer.step()

    train_accuracy = calculate_accuracy(outputs, y_train)

    model.eval()
    with torch.no_grad():
        test_outputs = model(X_test)
        test_loss = criterion(test_outputs, y_test)
        test_accuracy = calculate_accuracy(test_outputs, y_test)

    
    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss.item():.4f}, Train Accuracy: {train_accuracy.item():.4f}, Test Loss: {test_loss.item():.4f}, Test Accuracy: {test_accuracy.item():.4f}')
# Out:
# Epoch [1/100], Train Loss: 1.1224, Train Accuracy: 72.0830, Test Loss: 1.1522, Test Accuracy: 72.3328
# Epoch [2/100], Train Loss: 1.1224, Train Accuracy: 72.1483, Test Loss: 1.1522, Test Accuracy: 72.5285
# Epoch [3/100], Train Loss: 1.1224, Train Accuracy: 72.2054, Test Loss: 1.1521, Test Accuracy: 72.5938
# Epoch [4/100], Train Loss: 1.1223, Train Accuracy: 72.3116, Test Loss: 1.1521, Test Accuracy: 72.5938
# Epoch [5/100], Train Loss: 1.1223, Train Accuracy: 72.4586, Test Loss: 1.1521, Test Accuracy: 72.6264
# Epoch [6/100], Train Loss: 1.1223, Train Accuracy: 72.5484, Test Loss: 1.1521, Test Accuracy: 72.6917
# Epoch [7/100], Train Loss: 1.1223, Train Accuracy: 72.6219, Test Loss: 1.1521, Test Accuracy: 72.6917
# Epoch [8/100], Train Loss: 1.1223, Train Accuracy: 72.7035, Test Loss: 1.1521, Test Accuracy: 72.6917
# Epoch [9/100], Train Loss: 1.1223, Train Accuracy: 72.7933, Test Loss: 1.1521, Test Accuracy: 72.7243
# Epoch [10/100], Train Loss: 1.1223, Train Accuracy: 72.9158, Test Loss: 1.1521, Test Accuracy: 72.7896
# Epoch [11/100], Train Loss: 1.1222, Train Accuracy: 73.0546, Test Loss: 1.1520, Test Accuracy: 72.8222
# Epoch [12/100], Train Loss: 1.1222, Train Accuracy: 73.1281, Test Loss: 1.1520, Test Accuracy: 72.8874
# Epoch [13/100], Train Loss: 1.1222, Train Accuracy: 73.2424, Test Loss: 1.1520, Test Accuracy: 72.9853
# Epoch [14/100], Train Loss: 1.1222, Train Accuracy: 73.2914, Test Loss: 1.1520, Test Accuracy: 72.9853
# Epoch [15/100], Train Loss: 1.1222, Train Accuracy: 73.4139, Test Loss: 1.1520, Test Accuracy: 73.0506
# Epoch [16/100], Train Loss: 1.1222, Train Accuracy: 73.4792, Test Loss: 1.1520, Test Accuracy: 73.1484
# Epoch [17/100], Train Loss: 1.1222, Train Accuracy: 73.6099, Test Loss: 1.1520, Test Accuracy: 73.2790
# Epoch [18/100], Train Loss: 1.1221, Train Accuracy: 73.6752, Test Loss: 1.1520, Test Accuracy: 73.4421
# Epoch [19/100], Train Loss: 1.1221, Train Accuracy: 73.7813, Test Loss: 1.1519, Test Accuracy: 73.5400
# Epoch [20/100], Train Loss: 1.1221, Train Accuracy: 73.9038, Test Loss: 1.1519, Test Accuracy: 73.6052
# Epoch [21/100], Train Loss: 1.1221, Train Accuracy: 73.9773, Test Loss: 1.1519, Test Accuracy: 73.6705
# Epoch [22/100], Train Loss: 1.1221, Train Accuracy: 74.0671, Test Loss: 1.1519, Test Accuracy: 73.7357
# Epoch [23/100], Train Loss: 1.1221, Train Accuracy: 74.1406, Test Loss: 1.1519, Test Accuracy: 73.7357
# Epoch [24/100], Train Loss: 1.1221, Train Accuracy: 74.2467, Test Loss: 1.1519, Test Accuracy: 73.7684
# Epoch [25/100], Train Loss: 1.1220, Train Accuracy: 74.3284, Test Loss: 1.1519, Test Accuracy: 73.8010
# Epoch [26/100], Train Loss: 1.1220, Train Accuracy: 74.3937, Test Loss: 1.1518, Test Accuracy: 73.8662
# Epoch [27/100], Train Loss: 1.1220, Train Accuracy: 74.4591, Test Loss: 1.1518, Test Accuracy: 73.9641
# Epoch [28/100], Train Loss: 1.1220, Train Accuracy: 74.5407, Test Loss: 1.1518, Test Accuracy: 73.9641
# Epoch [29/100], Train Loss: 1.1220, Train Accuracy: 74.6305, Test Loss: 1.1518, Test Accuracy: 74.0294
# Epoch [30/100], Train Loss: 1.1220, Train Accuracy: 74.7122, Test Loss: 1.1518, Test Accuracy: 74.1272
# Epoch [31/100], Train Loss: 1.1220, Train Accuracy: 74.7857, Test Loss: 1.1518, Test Accuracy: 74.2578
# Epoch [32/100], Train Loss: 1.1219, Train Accuracy: 74.8428, Test Loss: 1.1518, Test Accuracy: 74.2904
# Epoch [33/100], Train Loss: 1.1219, Train Accuracy: 74.9163, Test Loss: 1.1518, Test Accuracy: 74.3556
# Epoch [34/100], Train Loss: 1.1219, Train Accuracy: 75.0061, Test Loss: 1.1517, Test Accuracy: 74.3230
# Epoch [35/100], Train Loss: 1.1219, Train Accuracy: 75.0959, Test Loss: 1.1517, Test Accuracy: 74.3556
# Epoch [36/100], Train Loss: 1.1219, Train Accuracy: 75.1449, Test Loss: 1.1517, Test Accuracy: 74.4535
# Epoch [37/100], Train Loss: 1.1219, Train Accuracy: 75.2266, Test Loss: 1.1517, Test Accuracy: 74.4861
# Epoch [38/100], Train Loss: 1.1219, Train Accuracy: 75.3082, Test Loss: 1.1517, Test Accuracy: 74.5188
# Epoch [39/100], Train Loss: 1.1218, Train Accuracy: 75.3246, Test Loss: 1.1517, Test Accuracy: 74.5514
# Epoch [40/100], Train Loss: 1.1218, Train Accuracy: 75.3817, Test Loss: 1.1517, Test Accuracy: 74.6166
# Epoch [41/100], Train Loss: 1.1218, Train Accuracy: 75.4144, Test Loss: 1.1517, Test Accuracy: 74.6819
# Epoch [42/100], Train Loss: 1.1218, Train Accuracy: 75.5287, Test Loss: 1.1516, Test Accuracy: 74.7145
# Epoch [43/100], Train Loss: 1.1218, Train Accuracy: 75.6267, Test Loss: 1.1516, Test Accuracy: 74.7798
# Epoch [44/100], Train Loss: 1.1218, Train Accuracy: 75.6920, Test Loss: 1.1516, Test Accuracy: 74.7798
# Epoch [45/100], Train Loss: 1.1218, Train Accuracy: 75.7410, Test Loss: 1.1516, Test Accuracy: 74.9755
# Epoch [46/100], Train Loss: 1.1217, Train Accuracy: 75.8390, Test Loss: 1.1516, Test Accuracy: 75.1713
# Epoch [47/100], Train Loss: 1.1217, Train Accuracy: 75.9451, Test Loss: 1.1516, Test Accuracy: 75.2692
# Epoch [48/100], Train Loss: 1.1217, Train Accuracy: 76.0023, Test Loss: 1.1516, Test Accuracy: 75.3670
# Epoch [49/100], Train Loss: 1.1217, Train Accuracy: 76.0676, Test Loss: 1.1515, Test Accuracy: 75.5302
# Epoch [50/100], Train Loss: 1.1217, Train Accuracy: 76.0921, Test Loss: 1.1515, Test Accuracy: 75.5628
# Epoch [51/100], Train Loss: 1.1217, Train Accuracy: 76.1901, Test Loss: 1.1515, Test Accuracy: 75.6281
# Epoch [52/100], Train Loss: 1.1217, Train Accuracy: 76.2391, Test Loss: 1.1515, Test Accuracy: 75.6281
# Epoch [53/100], Train Loss: 1.1216, Train Accuracy: 76.3044, Test Loss: 1.1515, Test Accuracy: 75.6281
# Epoch [54/100], Train Loss: 1.1216, Train Accuracy: 76.3289, Test Loss: 1.1515, Test Accuracy: 75.6933
# Epoch [55/100], Train Loss: 1.1216, Train Accuracy: 76.4024, Test Loss: 1.1515, Test Accuracy: 75.7586
# Epoch [56/100], Train Loss: 1.1216, Train Accuracy: 76.4514, Test Loss: 1.1515, Test Accuracy: 75.8238
# Epoch [57/100], Train Loss: 1.1216, Train Accuracy: 76.4922, Test Loss: 1.1514, Test Accuracy: 75.8564
# Epoch [58/100], Train Loss: 1.1216, Train Accuracy: 76.5657, Test Loss: 1.1514, Test Accuracy: 75.9543
# Epoch [59/100], Train Loss: 1.1216, Train Accuracy: 76.6310, Test Loss: 1.1514, Test Accuracy: 75.9543
# Epoch [60/100], Train Loss: 1.1215, Train Accuracy: 76.7208, Test Loss: 1.1514, Test Accuracy: 76.0196
# Epoch [61/100], Train Loss: 1.1215, Train Accuracy: 76.7862, Test Loss: 1.1514, Test Accuracy: 76.0848
# Epoch [62/100], Train Loss: 1.1215, Train Accuracy: 76.8841, Test Loss: 1.1514, Test Accuracy: 76.1175
# Epoch [63/100], Train Loss: 1.1215, Train Accuracy: 76.9331, Test Loss: 1.1514, Test Accuracy: 76.1827
# Epoch [64/100], Train Loss: 1.1215, Train Accuracy: 76.9740, Test Loss: 1.1513, Test Accuracy: 76.2480
# Epoch [65/100], Train Loss: 1.1215, Train Accuracy: 77.0066, Test Loss: 1.1513, Test Accuracy: 76.2480
# Epoch [66/100], Train Loss: 1.1215, Train Accuracy: 77.0638, Test Loss: 1.1513, Test Accuracy: 76.1827
# Epoch [67/100], Train Loss: 1.1214, Train Accuracy: 77.0883, Test Loss: 1.1513, Test Accuracy: 76.2480
# Epoch [68/100], Train Loss: 1.1214, Train Accuracy: 77.1373, Test Loss: 1.1513, Test Accuracy: 76.2806
# Epoch [69/100], Train Loss: 1.1214, Train Accuracy: 77.2352, Test Loss: 1.1513, Test Accuracy: 76.3132
# Epoch [70/100], Train Loss: 1.1214, Train Accuracy: 77.2761, Test Loss: 1.1513, Test Accuracy: 76.4111
# Epoch [71/100], Train Loss: 1.1214, Train Accuracy: 77.3414, Test Loss: 1.1513, Test Accuracy: 76.5742
# Epoch [72/100], Train Loss: 1.1214, Train Accuracy: 77.4394, Test Loss: 1.1512, Test Accuracy: 76.6721
# Epoch [73/100], Train Loss: 1.1214, Train Accuracy: 77.4475, Test Loss: 1.1512, Test Accuracy: 76.7047
# Epoch [74/100], Train Loss: 1.1213, Train Accuracy: 77.4802, Test Loss: 1.1512, Test Accuracy: 76.7374
# Epoch [75/100], Train Loss: 1.1213, Train Accuracy: 77.4965, Test Loss: 1.1512, Test Accuracy: 76.8026
# Epoch [76/100], Train Loss: 1.1213, Train Accuracy: 77.5619, Test Loss: 1.1512, Test Accuracy: 76.9005
# Epoch [77/100], Train Loss: 1.1213, Train Accuracy: 77.6108, Test Loss: 1.1512, Test Accuracy: 76.9331
# Epoch [78/100], Train Loss: 1.1213, Train Accuracy: 77.7007, Test Loss: 1.1512, Test Accuracy: 76.9984
# Epoch [79/100], Train Loss: 1.1213, Train Accuracy: 77.7823, Test Loss: 1.1511, Test Accuracy: 77.1289
# Epoch [80/100], Train Loss: 1.1213, Train Accuracy: 77.8150, Test Loss: 1.1511, Test Accuracy: 77.1289
# Epoch [81/100], Train Loss: 1.1212, Train Accuracy: 77.8395, Test Loss: 1.1511, Test Accuracy: 77.1615
# Epoch [82/100], Train Loss: 1.1212, Train Accuracy: 77.9130, Test Loss: 1.1511, Test Accuracy: 77.2268
# Epoch [83/100], Train Loss: 1.1212, Train Accuracy: 77.9946, Test Loss: 1.1511, Test Accuracy: 77.2920
# Epoch [84/100], Train Loss: 1.1212, Train Accuracy: 78.0599, Test Loss: 1.1511, Test Accuracy: 77.3573
# Epoch [85/100], Train Loss: 1.1212, Train Accuracy: 78.1171, Test Loss: 1.1511, Test Accuracy: 77.4225
# Epoch [86/100], Train Loss: 1.1212, Train Accuracy: 78.1661, Test Loss: 1.1511, Test Accuracy: 77.4225
# Epoch [87/100], Train Loss: 1.1212, Train Accuracy: 78.1824, Test Loss: 1.1510, Test Accuracy: 77.5530
# Epoch [88/100], Train Loss: 1.1211, Train Accuracy: 78.2151, Test Loss: 1.1510, Test Accuracy: 77.6509
# Epoch [89/100], Train Loss: 1.1211, Train Accuracy: 78.2641, Test Loss: 1.1510, Test Accuracy: 77.7488
# Epoch [90/100], Train Loss: 1.1211, Train Accuracy: 78.3294, Test Loss: 1.1510, Test Accuracy: 77.8140
# Epoch [91/100], Train Loss: 1.1211, Train Accuracy: 78.3784, Test Loss: 1.1510, Test Accuracy: 77.8793
# Epoch [92/100], Train Loss: 1.1211, Train Accuracy: 78.4355, Test Loss: 1.1510, Test Accuracy: 77.9119
# Epoch [93/100], Train Loss: 1.1211, Train Accuracy: 78.5254, Test Loss: 1.1510, Test Accuracy: 78.0750
# Epoch [94/100], Train Loss: 1.1211, Train Accuracy: 78.5988, Test Loss: 1.1509, Test Accuracy: 78.1729
# Epoch [95/100], Train Loss: 1.1210, Train Accuracy: 78.6315, Test Loss: 1.1509, Test Accuracy: 78.1729
# Epoch [96/100], Train Loss: 1.1210, Train Accuracy: 78.7050, Test Loss: 1.1509, Test Accuracy: 78.1729
# Epoch [97/100], Train Loss: 1.1210, Train Accuracy: 78.7621, Test Loss: 1.1509, Test Accuracy: 78.2055
# Epoch [98/100], Train Loss: 1.1210, Train Accuracy: 78.7866, Test Loss: 1.1509, Test Accuracy: 78.3034
# Epoch [99/100], Train Loss: 1.1210, Train Accuracy: 78.8601, Test Loss: 1.1509, Test Accuracy: 78.3687
# Epoch [100/100], Train Loss: 1.1210, Train Accuracy: 78.9091, Test Loss: 1.1509, Test Accuracy: 78.3687

# %%
# printing classification report
model.eval()
with torch.no_grad():
    test_outputs = model(X_test)
    test_predictions = test_outputs.round().numpy()
    print(f'Classification Report:\n{classification_report(y_test.numpy(), test_predictions)}')
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.85      0.88      2739
#          1.0       0.15      0.22      0.18       326
#
#     accuracy                           0.78      3065
#    macro avg       0.53      0.54      0.53      3065
# weighted avg       0.82      0.78      0.80      3065
